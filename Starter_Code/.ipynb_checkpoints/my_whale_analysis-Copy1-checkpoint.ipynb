# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_csv = Path("Resources/whale_returns.csv") 
whale_df = pd.read_csv(whale_csv, index_col = "Date", infer_datetime_format = True, parse_dates = True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace = True)
print(whale_df)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_csv = Path("Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
snp_csv = Path("Resources/sp500_history.csv")
snp_close_df = pd.read_csv(snp_csv, index_col = "Date", infer_datetime_format=True, parse_dates=True)
snp_close_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
snp_close_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
snp_close_df['Close'] = snp_close_df['Close'].astype(str).str.replace('$','')
snp_close_df['Close'] = snp_close_df['Close'].astype("float")
snp_close_df.head()
# Out:
# C:\Users\Ray\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Daily Returns
snp_df = snp_close_df.pct_change()
# snp_daily_returns.head()

# %%
# Drop nulls
snp_df.dropna(inplace=True)
snp_df.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
snp_df.rename(columns={'Close':'SNP Close'}, inplace=True)

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_df, algo_df, snp_df], axis="columns", join="inner")
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  SNP Close
# Date
# 2015-03-03 -0.000949   0.004408
# 2015-03-04  0.002416  -0.001195
# 2015-03-05  0.004323   0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
combined_df.plot(title = "Daily Returns for each Portfolio",figsize=(20,10), ylabel='Daily Returns %')
# Out:
# <AxesSubplot:title={'center':'Daily Returns for each Portfolio'}, xlabel='Date', ylabel='Daily Returns %'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cum_returns = (1 + combined_df).cumprod()
# comb_returns.head()

# Plot cumulative returns
cum_returns.plot(figsize=(20,10), title = "Cumulative Returns for All Portfolios", ylabel = 'Daily Cumulative Returns %' )
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns for All Portfolios'}, xlabel='Date', ylabel='Daily Cumulative Returns %'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# SNP Close                      0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
snp_std = combined_df['SNP Close'].std()

# Determine which portfolios are riskier than the S&P 500
combined_df.std() > snp_std
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# SNP Close                      False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annual_combined_std = combined_df.std() * np.sqrt(252)
annual_combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# SNP Close                      0.136313
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_df_std21 = combined_df.rolling(window=21).std()
# Plot the rolling standard deviation
combined_df_std21.plot(figsize=(20,10), title = "21-Day Rolling STD for all Portfolios")
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling STD for all Portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
price_correlation = combined_df.corr()
# Display the correlation matrix
sns.heatmap(price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
# Covariance of Berkshire Hathaway Inc vs S&P500 returns
covariance = combined_df['BERKSHIRE HATHAWAY INC'].cov(combined_df["SNP Close"])

# # Calculate variance of S&P 500
variance = combined_df["SNP Close"].var()
# variance
# Computing beta
bh_beta = covariance / variance
bh_beta
# # Plot beta trend = 60-day rolling beta between the single portfolio and the S&P 500
rolling_covariance = combined_df['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_df["SNP Close"])
rolling_variance = combined_df["SNP Close"].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20,10), title="Rolling 60-Day Beta of Berkshire Hathaway Inc")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Berkshire Hathaway Inc'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
# .ewm(halflife=21)
combined_df_21ewm = combined_df.ewm(halflife=21).std()
combined_df_21ewm.plot(figsize=(20,10), title = "EWM 21-Day Half-Life")
# Out:
# <AxesSubplot:title={'center':'EWM 21-Day Half-Life'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# SNP Close                     -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(title= "Sharpe Ratios for 7 Portfolios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios for 7 Portfolios'}>

# %%
### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# Write your answer here!
# Looks like Algo 1 is the clear winner...nice work Harold you algolord!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock "goog"
goog_csv = Path("Resources/goog_historical.csv") 
goog_df = pd.read_csv(goog_csv, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True)
goog_df.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Reading data from 2nd stock "aapl"
aapl_csv = Path("Resources/aapl_historical.csv") 
aapl_df = pd.read_csv(aapl_csv, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True)
aapl_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Reading data from 3rd stock "cost"
cost_csv = Path("Resources/cost_historical.csv") 
cost_df = pd.read_csv(cost_csv, index_col = "Trade DATE", infer_datetime_format = True, parse_dates = True)
cost_df.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Combine all stocks in a single DataFrame
gac_combined_df = pd.concat([goog_df, aapl_df, cost_df], axis="columns", join="inner")
gac_combined_df.head()
# Combined_Portfolios_21days = Combined_Portfolios.sort_index(ascending=False)[:20]
# Out:
#            Symbol     NOCP Symbol    NOCP Symbol    NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38   AAPL  200.72   COST  243.47
# 2019-05-08   GOOG  1166.27   AAPL  202.90   COST  241.34
# 2019-05-07   GOOG  1174.10   AAPL  202.86   COST  240.18
# 2019-05-06   GOOG  1189.39   AAPL  208.48   COST  244.23
# 2019-05-03   GOOG  1185.40   AAPL  211.75   COST  244.62

# %%
# Reset Date index
# gac_combined_df.reset_index() - I wasn't sure if "reset" was actually the correct function here?
gac_combined_df.sort_index(inplace=True)
gac_combined_df.head()
# Out:
#            Symbol     NOCP Symbol    NOCP Symbol    NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26   AAPL  188.59   COST  195.76
# 2018-05-14   GOOG  1100.20   AAPL  188.15   COST  195.88
# 2018-05-15   GOOG  1079.23   AAPL  186.44   COST  195.48
# 2018-05-16   GOOG  1081.77   AAPL  188.18   COST  198.71
# 2018-05-17   GOOG  1078.59   AAPL  186.99   COST  199.60

# %%
# Reorganize portfolio data by having a column per symbol
gac_combined_df.columns = ['X', 'GOOG', 'X', "AAPL", "X", "COST"]
gac_combined_df.drop(columns= "X", inplace= True)
gac_combined_df.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
# Calculate daily returns
gac_daily_returns= gac_combined_df.pct_change()
# Drop NAs
gac_daily_returns.dropna(inplace= True)
# Display sample data
gac_daily_returns.head()
# Out:
#                 GOOG      AAPL      COST
# Trade DATE
# 2018-05-14  0.001766 -0.002333  0.000613
# 2018-05-15 -0.019060 -0.009088 -0.002042
# 2018-05-16  0.002354  0.009333  0.016523
# 2018-05-17 -0.002940 -0.006324  0.004479
# 2018-05-18 -0.011339 -0.003637 -0.003206

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
portfolio_returns = gac_daily_returns.dot(weights)
# Display sample data
portfolio_returns.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_combined_df = pd.concat([portfolio_returns, combined_df], axis="columns", join="inner")
all_combined_df.head()
# Out:
#                    0  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14  0.000015                   0.000000            0.000000
# 2018-05-15 -0.010064                  -0.000726           -0.001409
# 2018-05-16  0.009403                   0.008637            0.006244
# 2018-05-17 -0.001595                  -0.001955            0.002524
# 2018-05-18 -0.006061                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2  SNP Close
# 2018-05-14  0.001635   0.006889
# 2018-05-15 -0.001139  -0.004044
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_combined_df.sort_index(inplace=True)
# Rename all portfolios as symbols
all_combined_df.columns = ['MYPF', 'SFMT', 'PAUL', 'TGMT', 'BHWI', 'ALG1', 'ALG2', 'SNP5']
# all_combined_df.head()
all_daily_returns= all_combined_df.pct_change()
all_daily_returns.replace([np.inf, -np.inf], np.nan, inplace=True)
all_daily_returns.dropna(inplace= True)
all_daily_returns.head()
# Out:
#                 MYPF       SFMT      PAUL      TGMT      BHWI      ALG1  \
# 2018-05-16 -1.934383 -12.898756 -5.432331 -2.717996 -1.295083  1.050169
# 2018-05-17 -1.169604  -1.226402 -0.595815 -2.143738 -2.192535  1.987055
# 2018-05-18  2.800180   1.228260 -2.058872  1.047487 -0.569648 -1.368007
# 2018-05-21 -2.253972  -1.574523 -0.552753 -0.910150 -5.688231 -2.209175
# 2018-05-22 -1.652866  -1.936808 -1.977019 -0.792138 -1.236702 -4.632835
#
#                 ALG2      SNP5
# 2018-05-16 -3.933589 -1.211807
# 2018-05-17  0.557966  2.081071
# 2018-05-18 -1.479620 -3.778360
# 2018-05-21 -2.972432 -1.428990
# 2018-05-22 -2.143030 -2.029328

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annual_all_combined_std = all_combined_df.std() * np.sqrt(252)
annual_all_combined_std
# Out:
# MYPF    0.211627
# SFMT    0.146812
# PAUL    0.116928
# TGMT    0.232898
# BHWI    0.247305
# ALG1    0.133927
# ALG2    0.139499
# SNP5    0.152469
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
all_combined_df_std21 = all_combined_df.rolling(window=21).std()
# Plot the rolling standard deviation
all_combined_df_std21.plot(figsize=(20,10), title = "21-Day Rolling STD for All Combined Portfolios")
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling STD for All Combined Portfolios'}>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_price_correlation = all_combined_df.corr()
# Display the correlation matrix
sns.heatmap(all_price_correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# Calculate covariance of my portfolio returns vs S&P500 returns
covariance = all_combined_df["MYPF"].cov(all_combined_df["SNP5"])
# Calculate variance of S&P 500
variance = all_combined_df["SNP5"].var()
# Computing beta
my_beta = covariance / variance
# Plot beta trend = 60-day rolling beta between the single portfolio and the S&P 500
rolling_covariance = all_combined_df["MYPF"].rolling(window=60).cov(all_combined_df["SNP5"])
rolling_variance = all_combined_df["SNP5"].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20,5), title="Rolling 60-Day Beta of My Portfolio vs SNP500")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of My Portfolio vs SNP500'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios = (all_combined_df.mean() * 252) / (all_combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# MYPF    0.876152
# SFMT    0.380007
# PAUL    0.227577
# TGMT   -1.066635
# BHWI    0.103006
# ALG1    2.001260
# ALG2    0.007334
# SNP5   -0.427676
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(title= "Sharpe Ratios for all Portfolios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios for all Portfolios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
# 2nd place to Harold's ALG1 pf...damn you Harold and your algolordiness!  
# If I have time I will go back and add a couple new shares of my own selection to take on Harold with full force!
